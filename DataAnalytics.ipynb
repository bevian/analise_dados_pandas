# %% [markdown]
# <a href="https://colab.research.google.com/github/bevian/analise_dados_pandas/blob/main/DataAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalação

# %%
# !pip install polars

# %%
import pandas as pd
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',100)

# %% [markdown]
# Manipulação do arquivo

# %%
df = pd.read_csv('dados_enem_2021_BA.csv')

# %%
#mostra 5 primeiras linhas
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210051128744    2021                4       F                1
# 1  210054173438    2021                5       F                1
# 2  210052118573    2021                3       F                1
# 3  210052350230    2021               10       F                1
# 4  210053156861    2021                9       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# 1            2                 1                2                0          2
# 2            3                 1                2                0          2
# 3            2                 1                1                8          1
# 4            2                 1                1                5          1
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %%
#mostra as ultimas 5 linhas
df.tail()
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 20051  210054455085    2021                4       F                1
# 20052  210051209340    2021                3       M                1
# 20053  210051477118    2021                2       M                1
# 20054  210051051633    2021                4       F                1
# 20055  210052601908    2021                6       F                1
#
#        TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 20051            3                 1                2                0
# 20052            2                 1                2                0
# 20053            3                 1                2                0
# 20054            3                 1                2                0
# 20055            3                 1                1                3
#
#        TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC  NO_MUNICIPIO_ESC  \
# ...

# %% [markdown]
# *Os dados batem com o dicionário de dados*

# %% [markdown]
# **Levantamento de hipóteses: **
#
#
# 1.   Os alunos vão melhor dependendo da região?
# 2.   A idade intefere na nota?

# %%
df.head(n=100)
# Out:
#     NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0   210051128744    2021                4       F                1
# 1   210054173438    2021                5       F                1
# 2   210052118573    2021                3       F                1
# 3   210052350230    2021               10       F                1
# 4   210053156861    2021                9       M                1
# ..           ...     ...              ...     ...              ...
# 95  210051133009    2021                3       F                1
# 96  210054025866    2021                6       F                1
# 97  210053352595    2021                2       F                1
# 98  210051020249    2021                4       M                1
# 99  210053374930    2021                3       M                1
#
#     TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0             3                 1                2                0
# ...

# %%
##Quantidade de linhas e coluna
df.shape
# Out:
# (20056, 51)

# %%
##Sumário do frame (quantos tem q são nulos, quantos estão preenchidos etc)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20056 entries, 0 to 20055
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            20056 non-null  int64
#  1   NU_ANO                  20056 non-null  int64
#  2   TP_FAIXA_ETARIA         20056 non-null  int64
#  3   TP_SEXO                 20056 non-null  object
#  4   TP_ESTADO_CIVIL         20056 non-null  int64
#  5   TP_COR_RACA             20056 non-null  int64
#  6   TP_NACIONALIDADE        20056 non-null  int64
#  7   TP_ST_CONCLUSAO         20056 non-null  int64
#  8   TP_ANO_CONCLUIU         20056 non-null  int64
#  9   TP_ESCOLA               20056 non-null  int64
#  10  TP_ENSINO               8789 non-null   float64
#  11  IN_TREINEIRO            20056 non-null  int64
#  12  CO_MUNICIPIO_ESC        3941 non-null   float64
#  13  NO_MUNICIPIO_ESC        3941 non-null   object
# ...

# %%
##Verifica missing
df.isna()
##Verifica missing por coluna
df.isna().sum()
# Out:
# NU_INSCRICAO                  0
# NU_ANO                        0
# TP_FAIXA_ETARIA               0
# TP_SEXO                       0
# TP_ESTADO_CIVIL               0
# TP_COR_RACA                   0
# TP_NACIONALIDADE              0
# TP_ST_CONCLUSAO               0
# TP_ANO_CONCLUIU               0
# TP_ESCOLA                     0
# TP_ENSINO                 11267
# IN_TREINEIRO                  0
# CO_MUNICIPIO_ESC          16115
# NO_MUNICIPIO_ESC          16115
# CO_UF_ESC                 16115
# SG_UF_ESC                 16115
# TP_DEPENDENCIA_ADM_ESC    16115
# TP_LOCALIZACAO_ESC        16115
# TP_SIT_FUNC_ESC           16115
# CO_MUNICIPIO_PROVA            0
# NO_MUNICIPIO_PROVA            0
# CO_UF_PROVA                   0
# SG_UF_PROVA                   0
# TP_PRESENCA_CN                0
# TP_PRESENCA_CH                0
# TP_PRESENCA_LC                0
# TP_PRESENCA_MT                0
# CO_PROVA_CN                4110
# CO_PROVA_CH                3479
# ...

# %%
##Missing em termos porcentuais
((df.isna().sum() / df.shape[0]) * 100).sort_values(ascending = False)

## df.isna().sum() = quantidade de nulos
## df.shape[0] == total de linhas
## do total de linhas, a quantidade de nulos de cada agrupamento é quantos %?
# Out:
# TP_DEPENDENCIA_ADM_ESC    80.350020
# SG_UF_ESC                 80.350020
# TP_SIT_FUNC_ESC           80.350020
# TP_LOCALIZACAO_ESC        80.350020
# CO_MUNICIPIO_ESC          80.350020
# NO_MUNICIPIO_ESC          80.350020
# CO_UF_ESC                 80.350020
# TP_ENSINO                 56.177702
# TX_GABARITO_MT            20.497607
# CO_PROVA_MT               20.492621
# CO_PROVA_CN               20.492621
# NU_NOTA_MT                20.492621
# TX_RESPOSTAS_CN           20.492621
# TX_RESPOSTAS_MT           20.492621
# TX_GABARITO_CN            20.492621
# NU_NOTA_CN                20.492621
# TX_GABARITO_CH            17.351416
# TX_GABARITO_LC            17.351416
# TP_STATUS_REDACAO         17.351416
# NU_NOTA_COMP1             17.351416
# NU_NOTA_COMP2             17.351416
# NU_NOTA_COMP3             17.351416
# NU_NOTA_COMP4             17.351416
# NU_NOTA_COMP5             17.351416
# NU_NOTA_REDACAO           17.351416
# NU_NOTA_CH                17.346430
# ...

# %%
##Sumário estatistico, MEDIA, PRIMEIRO QUARTIL, SEGUNDO QUARTIL, TERCEIRO QUARTIL
df.describe().transpose()
# Out:
#                           count          mean            std           min  \
# NU_INSCRICAO            20056.0  2.100527e+11  979792.945812  2.100510e+11
# NU_ANO                  20056.0  2.021000e+03       0.000000  2.021000e+03
# TP_FAIXA_ETARIA         20056.0  4.463303e+00       3.063680  1.000000e+00
# TP_ESTADO_CIVIL         20056.0  1.015806e+00       0.314686  0.000000e+00
# TP_COR_RACA             20056.0  2.321500e+00       0.902667  0.000000e+00
# TP_NACIONALIDADE        20056.0  1.032958e+00       0.194055  0.000000e+00
# TP_ST_CONCLUSAO         20056.0  1.705126e+00       0.685648  1.000000e+00
# TP_ANO_CONCLUIU         20056.0  1.609045e+00       3.262118  0.000000e+00
# TP_ESCOLA               20056.0  1.496809e+00       0.577212  1.000000e+00
# TP_ENSINO                8789.0  1.012402e+00       0.110677  1.000000e+00
# IN_TREINEIRO            20056.0  1.188173e-01       0.323581  0.000000e+00
# ...

# %%
##Quantidade de valores únicos por coluna
df.nunique().sort_values(ascending = True)
# Out:
# NU_ANO                        1
# SG_UF_PROVA                   1
# CO_UF_PROVA                   1
# TP_LINGUA                     2
# TP_SEXO                       2
# TP_LOCALIZACAO_ESC            2
# IN_TREINEIRO                  2
# TP_ENSINO                     2
# TP_PRESENCA_MT                3
# TP_PRESENCA_CH                3
# TP_PRESENCA_CN                3
# TP_PRESENCA_LC                3
# TP_ESCOLA                     3
# TP_SIT_FUNC_ESC               4
# TP_ST_CONCLUSAO               4
# TP_DEPENDENCIA_ADM_ESC        4
# TP_NACIONALIDADE              5
# TP_ESTADO_CIVIL               5
# TX_GABARITO_CH                6
# TP_COR_RACA                   6
# TX_GABARITO_LC                8
# TX_GABARITO_MT                8
# TP_STATUS_REDACAO             8
# TX_GABARITO_CN                9
# NU_NOTA_COMP4                10
# NU_NOTA_COMP1                10
# NU_NOTA_COMP2                10
# NU_NOTA_COMP5                11
# NU_NOTA_COMP3                11
# ...

# %% [markdown]
# *COMO SELECIONAR COLUNAS*

# %%
df.TP_ESCOLA
# Out:
# 0        2
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 11117    2
# 11118    2
# 11119    2
# 11120    1
# 11121    2
# Name: TP_ESCOLA, Length: 11122, dtype: int64

# %%
##Quantos de cada tipo da coluna
df.TP_ESCOLA.value_counts()
# Out:
# 1    6098
# 2    4634
# 3     390
# Name: TP_ESCOLA, dtype: int64

# %%
df['TP_ESCOLA']
# Out:
# 0        2
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 11117    2
# 11118    2
# 11119    2
# 11120    1
# 11121    2
# Name: TP_ESCOLA, Length: 11122, dtype: int64

# %%
##ILOC (linhas, coluna)
df.loc[:,'TP_SEXO']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        M
#         ..
# 11117    M
# 11118    F
# 11119    F
# 11120    F
# 11121    M
# Name: TP_SEXO, Length: 11122, dtype: object

# %%
df.loc[1:5,'TP_SEXO']
# Out:
# 1    F
# 2    F
# 3    F
# 4    M
# 5    M
# Name: TP_SEXO, dtype: object

# %%
##Selecionando múltiplas colunas com .loc
df.loc[:,['TP_SEXO','TP_ESCOLA']]
# Out:
#       TP_SEXO  TP_ESCOLA
# 0           F          2
# 1           F          2
# 2           F          2
# 3           F          1
# 4           M          1
# ...       ...        ...
# 11117       M          2
# 11118       F          2
# 11119       F          2
# 11120       F          1
# 11121       M          2
#
# [11122 rows x 2 columns]

# %%
##Iloc é com index da coluna
df.iloc[:,1]
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 11117    2021
# 11118    2021
# 11119    2021
# 11120    2021
# 11121    2021
# Name: NU_ANO, Length: 11122, dtype: int64

# %%
##Pegar pelo tipo
df.select_dtypes(include = object).columns.tolist()
# Out:
# ['TP_SEXO',
#  'NO_MUNICIPIO_ESC',
#  'SG_UF_ESC',
#  'NO_MUNICIPIO_PROVA',
#  'SG_UF_PROVA',
#  'TX_RESPOSTAS_CN',
#  'TX_RESPOSTAS_CH',
#  'TX_RESPOSTAS_LC',
#  'TX_RESPOSTAS_MT',
#  'TX_GABARITO_CN',
#  'TX_GABARITO_CH',
#  'TX_GABARITO_LC',
#  'TX_GABARITO_MT']

# %% [markdown]
# *FILTROS*

# %%
##Tipo mysql
df.query("TP_ESCOLA == 2")
# Out:
#       NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0     210051128744    2021                4       F                1
# 1     210054173438    2021                5       F                1
# 2     210052118573    2021                3       F                1
# 5     210053085526    2021                3       M                1
# 7     210053790986    2021                1       M                1
# ...            ...     ...              ...     ...              ...
# 4474  210053324216    2021                4       F                1
# 4479  210053307679    2021                3       F                1
# 4481  210051570593    2021                2       F                1
# 4483  210053021680    2021                2       F                1
# 4489  210053311211    2021                3       M                1
#
#       TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
##Média
df.query("TP_ESCOLA == 2").NU_NOTA_MT.mean()
# Out:
# 493.9701119157341

# %%
##Colocando funções do numpy
df.query("TP_ESCOLA == 2").NU_NOTA_MT.agg([np.mean,np.median])
# Out:
# mean      493.970112
# median    476.000000
# Name: NU_NOTA_MT, dtype: float64

# %%
##Operadores bitwise
df.query("(TP_ESCOLA == 2) | (TP_ESCOLA == 3)")
# Out:
#       NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0     210051128744    2021                4       F                1
# 1     210054173438    2021                5       F                1
# 2     210052118573    2021                3       F                1
# 5     210053085526    2021                3       M                1
# 7     210053790986    2021                1       M                1
# ...            ...     ...              ...     ...              ...
# 4479  210053307679    2021                3       F                1
# 4480  210052458119    2021                3       F                1
# 4481  210051570593    2021                2       F                1
# 4483  210053021680    2021                2       F                1
# 4489  210053311211    2021                3       M                1
#
#       TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
df.query("(TP_ESCOLA == 2) & (TP_SEXO == 'M')")
# Out:
#       NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 5     210053085526    2021                3       M                1
# 7     210053790986    2021                1       M                1
# 10    210052237624    2021                5       M                1
# 13    210052055613    2021                3       M                1
# 15    210052929031    2021                3       M                1
# ...            ...     ...              ...     ...              ...
# 4453  210054215565    2021                2       M                1
# 4459  210052789183    2021                3       M                1
# 4466  210053299085    2021                3       M                0
# 4467  210051144025    2021                3       M                1
# 4489  210053311211    2021                3       M                1
#
#       TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
##Teste logico
df.TP_SEXO == "M"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4487    False
# 4488    False
# 4489     True
# 4490    False
# 4491    False
# Name: TP_SEXO, Length: 4492, dtype: bool
